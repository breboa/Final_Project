# %%
import requests
import pandas as pd
import re
import json
from pandas.io.json import json_normalize #package for flattening json in pandas df
import pickle
from pprint import pprint

# %%
links_pickle = open("URL.pickle","rb")
links = pickle.load(links_pickle)
print(links)
# Out:
# ['https://www.sephora.com/product/luminous-silk-foundation-P393401?icid2=products%20grid:p393401', 'https://www.sephora.com/product/double-wear-stay-in-place-makeup-P378284?icid2=products%20grid:p378284', 'https://www.sephora.com/product/pro-filt-r-hydrating-longwear-foundation-P448702?icid2=products%20grid:p448702', 'https://www.sephora.com/product/pro-filtr-soft-matte-longwear-foundation-P87985432?icid2=products%20grid:p87985432', 'https://www.sephora.com/product/skin-fetish-sublime-perfection-foundation-P447519?icid2=products%20grid:p447519', 'https://www.sephora.com/product/your-skin-but-better-cc-cream-spf-50-P411885?icid2=products%20grid:p411885', 'https://www.sephora.com/product/ultra-hd-invisible-cover-foundation-P398321?icid2=products%20grid:p398321', 'https://www.sephora.com/product/tinted-moisturizer-broad-spectrum-P109936?icid2=products%20grid:p109936', 'https://www.sephora.com/product/teint-idole-ultra-24h-long-wear-foundation-P308201?icid2=products%20grid:p308201', 'https://www.sephora.com/product/born-this-way-P397517?icid2=products%20grid:p397517', 'https://www.sephora.com/product/power-fabric-longwear-high-cover-foundation-spf-25-P416785?icid2=products%20grid:p416785', 'https://www.sephora.com/product/natural-radiant-longwear-foundation-P427301?icid2=products%20grid:p427301', 'https://www.sephora.com/product/fauxfilter-foundation-P424302?icid2=products%20grid:p424302', 'https://www.sephora.com/product/diorskin-airflash-spray-foundation-P104914?icid2=products%20grid:p104914', 'https://www.sephora.com/product/airbrush-flawless-longwear-foundation-P448869?skuId=2245058&icid2=products%20grid:p448869', 'https://www.sephora.com/product/bareminerals-original-foundation-broad-spectrum-spf-15-P61003?icid2=products%20grid:p61003', 'https://www.sephora.com/product/backstage-face-body-foundation-P432500?icid2=products%20grid:p432500', 'https://www.sephora.com/product/sheer-glow-foundation-P247355?icid2=products%20grid:p247355', 'https://www.sephora.com/product/stay-naked-weightless-foundation-P447143?icid2=products%20grid:p447143', 'https://www.sephora.com/product/synchro-skin-self-refreshing-foundation-spf-30-P449106?icid2=products%20grid:p449106', 'https://www.sephora.com/product/tinted-moisturizer-broad-spectrum-oil-free-P140906?icid2=products%20grid:p140906', 'https://www.sephora.com/product/lock-it-tattoo-foundation-P311138?icid2=products%20grid:p311138', 'https://www.sephora.com/product/complexion-rescue-tinted-hydrating-gel-cream-P393356?icid2=products%20grid:p393356', 'https://www.sephora.com/product/pure-radiant-tinted-moisturizer-spf-30-pa-P302923?skuId=1774645&icid2=products%20grid:p302923', 'https://www.sephora.com/product/all-hours-full-coverage-matte-foundation-P421456?skuId=1969799&icid2=products%20grid:p421456', 'https://www.sephora.com/product/smooth-finish-foundation-powder-P381714?icid2=products%20grid:p381714', 'https://www.sephora.com/product/l-essentiel-natural-16h-wear-foundation-spf-20-P444578?icid2=products%20grid:p444578', 'https://www.sephora.com/product/matte-velvet-skin-blurring-powder-foundation-P443566?icid2=products%20grid:p443566', 'https://www.sephora.com/product/barepro-performance-wear-powder-foundation-P410543?icid2=products%20grid:p410543', 'https://www.sephora.com/product/amazonian-clay-12-hour-full-coverage-foundation-spf-15-P302918?icid2=products%20grid:p302918', 'https://www.sephora.com/product/sea-water-foundation-broad-spectrum-spf-15-P405102?icid2=products%20grid:p405102', 'https://www.sephora.com/product/vanish-seamless-finish-foundation-stick-P410532?icid2=products%20grid:p410532', 'https://www.sephora.com/product/your-skin-but-better-cc-oil-free-matte-with-spf-40-P433435?icid2=products%20grid:p433435', 'https://www.sephora.com/product/the-soft-fluid-long-wear-foundation-spf-20-P423742?icid2=products%20grid:p423742', 'https://www.sephora.com/product/forever-matte-foundation-P439940?icid2=products%20grid:p439940', 'https://www.sephora.com/product/peach-perfect-comfort-moisture ...

# %%
prod_ids = []
for link in links: 
    prod_ids.append(re.findall('P\d{5,6}', url_test))

# %%
prod_ids
# Out:
# [['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927'],
#  ['P109927']]

# %%
sample_size = prod_ids[0:2]

# %%
sample_size
# Out:
# [['P109927'], ['P109927']]

# %%
# url = 'https://api.bazaarvoice.com/data/reviews.json'


# for prod in prod_ids:

#     params = {
#       'Filter':f'ProductId:{prod[0]}',
#       'Sort': 'TotalPositiveFeedbackCount:desc',
#       'Limit': 30,
#       'Offset': 0,
#       'Include': 'Products,Comments',
#       'Stats': 'Reviews',
#       'passkey': 'rwbw526r2e7spptqd2qzbkp7',
#       'apiversion': 5.4
#     }

#     reviews = []
#     loop = 0

#     while True:
#         params['Offset'] = len(reviews)
    
#         r = requests.get(url, params=params)
        
#         #break if error or exceed length of reviews
#         if (r.status_code != 200) or (len(reviews) >= r.json()['TotalResults']):
#             break

#         # add the list of results to current results
#         reviews.extend(r.json()['Results'])

#         # Give a pause, so we don't get blocked
#         time.sleep(0.5)

#         # Show how many reviews we scraped
# print(len(reviews))

# %%
url = 'https://api.bazaarvoice.com/data/reviews.json'


for prod in sample_size:

    params = {
      'Filter':f'ProductId:{prod[0]}',
      'Sort': 'TotalPositiveFeedbackCount:desc',
      'Limit': 30,
      'Offset': 0,
      'Include': 'Products,Comments',
      'Stats': 'Reviews',
      'passkey': 'rwbw526r2e7spptqd2qzbkp7',
      'apiversion': 5.4
    }

    reviews = []
    loop = 0

    while True:
        params['Offset'] = len(reviews)
    
        r = requests.get(url, params=params)
        
        #break if error or exceed length of reviews
        if (r.status_code != 200) or (len(reviews) >= r.json()['TotalResults']):
            break

        # add the list of results to current results
        reviews.extend(r.json()['Results'])

        # Give a pause, so we don't get blocked
        time.sleep(0.5)

        # Show how many reviews we scraped
print(len(reviews))
# Out:
# 1406

# %%
review_df = pd.DataFrame(columns = [
                                    'ProductID',
                                    'UserNickname',
                                    'ReviewText',
                                    'Rating',
                                    'Age',
                                    'SkinTone', 
                                    'SkinType',
                                    'Title',
                                    'UserLocation',
                                    'StaffContext'])

# %%
sample= reviews[0:1]

# %%
sample

# %%
for review in reviews:
    for i in range(len(reviews)):
        table = {'UserNickname': reviews[i]['UserNickname'],
                 'Rating': reviews[i]['Rating'],
                 'ReviewText': reviews[i]['ReviewText'],
                 'SkinTone': reviews[i]['ContextDataValues']}
#         review_df.append(table, ignore_index=True)

# %%
table
# Out:
# {'UserNickname': 'ohyesshedid',
#  'Rating': 3,
#  'ReviewText': "I've only tried it once, because I ordered this online and guessed at the color. I ordered Flax but found it way too yellow for my light to medium skin with red/pink undertones.\n\nIt went on smoothly and kept shadow true all day. II will return and repurchase a more appropriate color for my skin tone.",
#  'SkinTone': {'beautyInsider': {'Value': 'yes',
#    'Id': 'beautyInsider',
#    'ValueLabel': "Yes - I'm a Beauty Insider",
#    'DimensionLabel': 'Beauty Insider'},
#   'age': {'Value': '35to44',
#    'Id': 'age',
#    'ValueLabel': '35-44',
#    'DimensionLabel': 'Age'}}}

# %%
for review in reviews:
    for i in range(len(reviews)):
        review_df['UserNickname'] = reviews[i]['UserNickname']

# %%
reviews[10]['ContextDataValues']['skinTone']['Value']
# Out:
# 'light'

# %%
reviews[5]
# Out:
# {'UserNickname': 'Maryam23',
#  'Rating': 5,
#  'ReviewText': "I haven't tried a lot of primers before this one, but I'll tell you its better than the urban decay one for suuure. I like to use it to neutralize my eye lids and sometimes thats all I do, no setting with eye shadow ir nothing. Definitely in my everyday drawer and a must in my collection!",
#  'ContextDataValues': {'StaffContext': {'Value': 'false',
#    'Id': 'StaffContext',
#    'ValueLabel': 'No',
#    'DimensionLabel': 'I am a Sephora employee'},
#   'IncentivizedReview': {'Value': 'false',
#    'Id': 'IncentivizedReview',
#    'ValueLabel': 'False',
#    'DimensionLabel': 'I received this product as a free sample'}},
#  'ProductId': 'P109927',
#  'Videos': [],
#  'CommentIds': [],
#  'Photos': [],
#  'TotalNegativeFeedbackCount': 2,
#  'RatingRange': 5,
#  'CampaignId': None,
#  'UserLocation': None,
#  'SecondaryRatingsOrder': [],
#  'TotalCommentCount': 0,
#  'ContextDataValuesOrder': ['IncentivizedReview', 'StaffContext'],
#  'ClientResponses': [],
#  'TagDimensionsOrder': [],
#  'TotalPositiveFeedbackCount': 18,
#  'IsRatingsOnly': False,
#  'LastModificationTime': '2019-07-21T16:51:00.000+00:00',
#  'Pros': None,
#  'ProductRecommendationIds': [],
#  'BadgesOrder': [],
#  'AuthorId': '5496715616',
#  'Helpfulness': 0.9,
#  'SubmissionTime': '2016-03-25T06:12:53.000+00:00',
#  'AdditionalFields': {},
#  'Title': "DOESN'T CREASE!",
#  'TotalFeedbackCount': 20,
#  'AdditionalFieldsOrder': [],
#  'ModerationStatus': 'APPROVED',
#  'IsFeatured': False,
#  'Cons': None,
#  'TagDimensions': {},
#  'SecondaryRatings': {},
#  'Badges': {},
#  'SubmissionId': '9sqhyhds9eo1ld7li1n09b682',
#  'IsSyndicated': False,
#  'IsRecommended': None,
#  'LastModeratedTime': '2016-03-25T06:15:02.000+00:00',
#  'Id': '62819452',
#  'ContentLocale': 'en_US'}

# %%
table
# Out:
# {'UserNickname': 'ohyesshedid',
#  'Rating': 3,
#  'ReviewText': "I've only tried it once, because I ordered this online and guessed at the color. I ordered Flax but found it way too yellow for my light to medium skin with red/pink undertones.\n\nIt went on smoothly and kept shadow true all day. II will return and repurchase a more appropriate color for my skin tone."}

# %%
review_df.append(table, ignore_index=True)
# Out:
#   ProductID UserNickname Rating IncentivizedReview SkinTone SkinType  \
# 0       NaN  ohyesshedid    NaN                NaN      NaN      NaN
#
#   ReviewText Title UserLocation StaffContext
# 0        NaN   NaN          NaN          NaN

# %%
output = output.append(dictionary, ignore_index=True)
print(output.head())

# %%
reviews[10]['UserNickname']
# Out:
# 'drodney'

# %%
table
# Out:
# {'UserNickname': 'ohyesshedid'}

# %%
review_df.head()
# Out:
# Empty DataFrame
# Columns: [ProductID, UserNickname, Rating, IncentivizedReview, SkinTone, SkinType, ReviewText, Title, UserLocation, StaffContext]
# Index: []

# %%
reviews[0]
# Out:
# {'UserNickname': 'SFValleymom',
#  'Rating': 5,
#  'ReviewText': "At 60, I am always looking for products that don't 'age' me, which means matte finishes on eyeshadows. I started using this several years ago in Wheat, which covered freckles/sundamage, while giving a nice touch of color. I've since added a second color, Linen, but Wheat is my go-to shade for light skin/green eyes/grey hair. I use it alone - no other shadow needed.",
#  'ContextDataValues': {'beautyInsider': {'Value': 'yesvib',
#    'Id': 'beautyInsider',
#    'ValueLabel': "Yes - I'm a VIB ",
#    'DimensionLabel': 'Beauty Insider'},
#   'eyeColor': {'Value': 'green',
#    'Id': 'eyeColor',
#    'ValueLabel': 'Green',
#    'DimensionLabel': 'Eye Color'},
#   'skinTone': {'Value': 'light',
#    'Id': 'skinTone',
#    'ValueLabel': 'Light',
#    'DimensionLabel': 'Skin Tone'},
#   'age': {'Value': 'over54',
#    'Id': 'age',
#    'ValueLabel': 'over 54',
#    'DimensionLabel': 'Age'}},
#  'ProductId': 'P109927',
#  'Videos': [],
#  'CommentIds': [],
#  'Photos': [],
#  'TotalNegativeFeedbackCount': 3,
#  'RatingRange': 5,
#  'CampaignId': 'BV_RATING_SUMMARY',
#  'UserLocation': 'North Hollywood, CA',
#  'SecondaryRatingsOrder': [],
#  'TotalCommentCount': 0,
#  'ContextDataValuesOrder': ['skinTone', 'eyeColor', 'age', 'beautyInsider'],
#  'TagDimensionsOrder': ['Pro'],
#  'ClientResponses': [],
#  'TotalPositiveFeedbackCount': 50,
#  'IsRatingsOnly': False,
#  'LastModificationTime': '2019-08-20T01:51:10.000+00:00',
#  'Pros': None,
#  'ProductRecommendationIds': [],
#  'BadgesOrder': ['yesvib'],
#  'AuthorId': '5062385078',
#  'Helpfulness': 0.943396,
#  'SubmissionTime': '2015-02-18T20:35:58.000+00:00',
#  'AdditionalFields': {},
#  'Title': 'Easy on the eyes (and skin)',
#  'TotalFeedbackCount': 53,
#  'AdditionalFieldsOrder': [],
#  'ModerationStatus': 'APPROVED',
#  'IsFeatured': False,
#  'Cons': None,
#  'TagDimensions': {'Pro': {'Label': 'Pros',
#    'Values': ['creamy', 'crease resistant'],
#    'Id': 'Pro'}},
#  'SecondaryRatings': {},
#  'Badges': {'yesvib': {'ContentType': 'REVIEW',
#    'Id': 'yesvib',
#    'BadgeType': 'Custom'}},
#  'SubmissionId': 'ai3y4vzhulkcqm7pxawufmgic',
#  'IsSyndicated': False,
#  'IsRecommended': None,
#  'LastModeratedTime': '2015-02-18T20:45:08.000+00:00',
#  'Id': '42860444',
#  'ContentLocale': 'en_US'}

# %%
for i in reviews[0:1]:
    print(i)
# Out:
# {'UserNickname': 'marysells', 'Rating': 5, 'ReviewText': "I'd been on the fence about purchasing this for a long time...I am a self-confessed product junkie and I have plenty of foundations I should be using up before buying more. I received a sample of this in 5.5, which is darker than I would ever go. But I still tried it out of curiosity...it wasn't really off the charts too dark and I loved the way it made my skin look. Sooooo...during the 15% off VIB sale I bought this in 4.5. The very first day I tried it, I still wasn't 100% sold. But then I went to the DMV and after looking at my license (and I assume my birthdate)  the clerk asked me what I use on my skin.  No kidding!!! Ok, I'm sold. Hahaha! Buy it, trust me.", 'ContextDataValues': {'skinType': {'Value': 'normal', 'Id': 'skinType', 'ValueLabel': 'Normal', 'DimensionLabel': 'Skin Type'}, 'beautyInsider': {'Value': 'yes', 'Id': 'beautyInsider', 'ValueLabel': "Yes - I'm a Beauty Insider", 'DimensionLabel': 'Beauty Insider'}, 'eyeColor': {'Value': 'hazel', 'Id': 'eyeColor', 'ValueLabel': 'Hazel', 'DimensionLabel': 'Eye Color'}, 'StaffContext': {'Value': 'false', 'Id': 'StaffContext', 'ValueLabel': 'No', 'DimensionLabel': 'I am a Sephora employee'}, 'skinTone': {'Value': 'fair', 'Id': 'skinTone', 'ValueLabel': 'Fair', 'DimensionLabel': 'Skin Tone'}, 'IncentivizedReview': {'Value': 'false', 'Id': 'IncentivizedReview', 'ValueLabel': 'False', 'DimensionLabel': 'I received this product as a free sample'}, 'age': {'Value': '45to54', 'Id': 'age', 'ValueLabel': '45-54', 'DimensionLabel': 'Age'}}, 'ProductId': 'P393401', 'Videos': [], 'CommentIds': [], 'Photos': [], 'TotalNegativeFeedbackCount': 31, 'RatingRange': 5, 'CampaignId': 'BV_RATING_SUMMARY', 'UserLocation': 'Tucson, AZ', 'SecondaryRatingsOrder': [], 'TotalCommentCount': 0, 'ContextDataValuesOrder': ['skinType', 'skinTone', 'eyeColor', 'age', 'beautyInsider', 'IncentivizedReview', 'StaffContext'], 'TagDimensionsOrder': ['Pro'], 'ClientResponses': [], 'TotalPositiveFeedbackCount': 249, 'IsRatingsOnly': False, 'LastModificationTime': '2019-09-04T13:27:18.000+00:00', 'Pros': None, 'ProductRecommendationIds': [], 'BadgesOrder': ['beautyInsider'], 'AuthorId': '1331777113', 'Helpfulness': 0.889286, 'SubmissionTime': '2016-04-18T19:00:26.000+00:00', 'AdditionalFields': {}, 'Title': 'It really is all that!!!', 'TotalFeedbackCount': 280, 'AdditionalFieldsOrder': [], 'ModerationStatus': 'APPROVED', 'IsFeatured': False, 'Cons': None, 'TagDimensions': {'Pro': {'Label': 'Pros', 'Values': ['buildable coverage'], 'Id': 'Pro'}}, 'SecondaryRatings': {}, 'Badges': {'beautyInsider': {'ContentType': 'REVIEW', 'Id': 'beautyInsider', 'BadgeType': 'Custom'}}, 'SubmissionId': '2fkq9qns6ot235xrvactg59sc', 'IsSyndicated': False, 'IsRecommended': None, 'LastModeratedTime': '2016-04-18T19:15:06.000+00:00', 'Id': '63994076', 'ContentLocale': 'en_US'}

# %%
print reviews
# Out:
# [{'UserNickname': 'marysells',
#   'Rating': 5,
#   'ReviewText': "I'd been on the fence about purchasing this for a long time...I am a self-confessed product junkie and I have plenty of foundations I should be using up before buying more. I received a sample of this in 5.5, which is darker than I would ever go. But I still tried it out of curiosity...it wasn't really off the charts too dark and I loved the way it made my skin look. Sooooo...during the 15% off VIB sale I bought this in 4.5. The very first day I tried it, I still wasn't 100% sold. But then I went to the DMV and after looking at my license (and I assume my birthdate)  the clerk asked me what I use on my skin.  No kidding!!! Ok, I'm sold. Hahaha! Buy it, trust me.",
#   'ContextDataValues': {'skinType': {'Value': 'normal',
#     'Id': 'skinType',
#     'ValueLabel': 'Normal',
#     'DimensionLabel': 'Skin Type'},
#    'beautyInsider': {'Value': 'yes',
#     'Id': 'beautyInsider',
#     'ValueLabel': "Yes - I'm a Beauty Insider",
#     'DimensionLabel': 'Beauty Insider'},
#    'eyeColor': {'Value': 'hazel',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Hazel',
#     'DimensionLabel': 'Eye Color'},
#    'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'skinTone': {'Value': 'fair',
#     'Id': 'skinTone',
#     'ValueLabel': 'Fair',
#     'DimensionLabel': 'Skin Tone'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'},
#    'age': {'Value': '45to54',
#     'Id': 'age',
#     'ValueLabel': '45-54',
#     'DimensionLabel': 'Age'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 31,
#   'RatingRange': 5,
#   'CampaignId': 'BV_RATING_SUMMARY',
#   'UserLocation': 'Tucson, AZ',
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['skinType',
#    'skinTone',
#    'eyeColor',
#    'age',
#    'beautyInsider',
#    'IncentivizedReview',
#    'StaffContext'],
#   'TagDimensionsOrder': ['Pro'],
#   'ClientResponses': [],
#   'TotalPositiveFeedbackCount': 248,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-09-03T00:55:07.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': ['beautyInsider'],
#   'AuthorId': '1331777113',
#   'Helpfulness': 0.888889,
#   'SubmissionTime': '2016-04-18T19:00:26.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'It really is all that!!!',
#   'TotalFeedbackCount': 279,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {'Pro': {'Label': 'Pros',
#     'Values': ['buildable coverage'],
#     'Id': 'Pro'}},
#   'SecondaryRatings': {},
#   'Badges': {'beautyInsider': {'ContentType': 'REVIEW',
#     'Id': 'beautyInsider',
#     'BadgeType': 'Custom'}},
#   'SubmissionId': '2fkq9qns6ot235xrvactg59sc',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2016-04-18T19:15:06.000+00:00',
#   'Id': '63994076',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'kinakelly',
#   'Rating': 4,
#   'ReviewText': 'Best foundation ever, lightweight, flawless and good coverage',
#   'ContextDataValues': {'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 51,
#   'RatingRange': 5,
#   'CampaignId': None,
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['IncentivizedReview', 'StaffContext'],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 214,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-09-01T21:36:37.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': [],
#   'AuthorId': '7910927000',
#   'Helpfulness': 0.807547,
#   'SubmissionTime': '2016-11-20T06:20:36.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'great foundation',
#   'TotalFeedbackCount': 265,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {},
#   'SubmissionId': 'oyglyfjijrzyfmudqftwzsg17',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2016-11-20T06:30:02.000+00:00',
#   'Id': '76585477',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'chards',
#   'Rating': 5,
#   'ReviewText': "I have extremely dry skin with a pale complexion and have tried numerous foundations trying to find the best one that suits me and my skin. Also even though its one of the more expensive ones you do get a lot of use of it. I use it nearly everyday and still haven't ran out and I can't remember when I first purchased it.",
#   'ContextDataValues': {'skinType': {'Value': 'dry',
#     'Id': 'skinType',
#     'ValueLabel': 'Dry',
#     'DimensionLabel': 'Skin Type'},
#    'beautyInsider': {'Value': 'yesvibr',
#     'Id': 'beautyInsider',
#     'ValueLabel': "Yes - I'm a VIB Rouge ",
#     'DimensionLabel': 'Beauty Insider'},
#    'eyeColor': {'Value': 'blue',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Blue',
#     'DimensionLabel': 'Eye Color'},
#    'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'skinTone': {'Value': 'fair',
#     'Id': 'skinTone',
#     'ValueLabel': 'Fair',
#     'DimensionLabel': 'Skin Tone'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'},
#    'age': {'Value': '18to24',
#     'Id': 'age',
#     'ValueLabel': '18-24',
#     'DimensionLabel': 'Age'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 15,
#   'RatingRange': 5,
#   'CampaignId': 'BV_RATING_SUMMARY',
#   'UserLocation': 'Toronto, Canada',
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['skinType',
#    'skinTone',
#    'eyeColor',
#    'age',
#    'beautyInsider',
#    'IncentivizedReview',
#    'StaffContext'],
#   'TagDimensionsOrder': ['Pro'],
#   'ClientResponses': [],
#   'TotalPositiveFeedbackCount': 192,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-09-03T04:55:24.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': ['yesvibr'],
#   'AuthorId': '5720867145',
#   'Helpfulness': 0.927536,
#   'SubmissionTime': '2016-10-08T06:01:13.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'My favourite foundation.',
#   'TotalFeedbackCount': 207,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {'Pro': {'Label': 'Pros',
#     'Values': ['buildable coverage', 'long wearing', 'oil-free'],
#     'Id': 'Pro'}},
#   'SecondaryRatings': {},
#   'Badges': {'yesvibr': {'ContentType': 'REVIEW',
#     'Id': 'yesvibr',
#     'BadgeType': 'Custom'}},
#   'SubmissionId': 'isyj97kk6i9dts0d81slunadi',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2016-10-08T06:15:03.000+00:00',
#   'Id': '74126426',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'Angiiie',
#   'Rating': 5,
#   'ReviewText': "I love the finish of this foundation, it gives you a healthy, I'm born with perfect skin type of look.. who wouldn't want that ?! I have dry to normal skin and this works perfectly for me. I don't like a full coverage foundation because I like my foundation to look like skin, and this is exactly the result I get with Luminous Silk. I have shade 4 and 6 and use them separate or mix them together to get my perfect shade when my self tan is fading. For reference my natural skin is NC20 - shade 4 in luminous silk and when I self tan I'm about an NC30/35 which works perfectly with shade 6",
#   'ContextDataValues': {'skinType': {'Value': 'normal',
#     'Id': 'skinType',
#     'ValueLabel': 'Normal',
#     'DimensionLabel': 'Skin Type'},
#    'age': {'Value': '25to34',
#     'Id': 'age',
#     'ValueLabel': '25-34',
#     'DimensionLabel': 'Age'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 33,
#   'RatingRange': 5,
#   'CampaignId': 'BV_RATING_SUMMARY',
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['skinType', 'age'],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 185,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-09-01T14:40:13.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': [],
#   'AuthorId': '2075991660',
#   'Helpfulness': 0.848624,
#   'SubmissionTime': '2015-03-11T19:42:23.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'A-M-A-Z-I-N-G',
#   'TotalFeedbackCount': 218,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {},
#   'SubmissionId': 'lzkpoket6hjq2j0ie5uohi0wq',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2015-03-11T19:45:06.000+00:00',
#   'Id': '44135651',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'stephsimas95',
#   'Rating': 5,
#   'ReviewText': "I am IN LOVE with this foundation. The price hurts my heart a little bit lol but this looks flawless. It isn't thick but I think it's medium to full coverage (its buildable) I have combination skin and was nervous to try a luminous foundation but hours later it looks flawless still! I use Hourglass primer to prime my skin before hand and I set with a translucent powder and set it with a setting spray. Because I have combo skin the luminous shines through even with the setting powder. I LOVE THIS and will repurchase when the bottle is gone.",
#   'ContextDataValues': {'skinType': {'Value': 'combination',
#     'Id': 'skinType',
#     'ValueLabel': 'Combination',
#     'DimensionLabel': 'Skin Type'},
#    'beautyInsider': {'Value': 'yesvibr',
#     'Id': 'beautyInsider',
#     'ValueLabel': "Yes - I'm a VIB Rouge ",
#     'DimensionLabel': 'Beauty Insider'},
#    'eyeColor': {'Value': 'brown',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Brown',
#     'DimensionLabel': 'Eye Color'},
#    'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'skinTone': {'Value': 'light',
#     'Id': 'skinTone',
#     'ValueLabel': 'Light',
#     'DimensionLabel': 'Skin Tone'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'},
#    'age': {'Value': '18to24',
#     'Id': 'age',
#     'ValueLabel': '18-24',
#     'DimensionLabel': 'Age'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 29,
#   'RatingRange': 5,
#   'CampaignId': 'BV_RATING_SUMMARY',
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['skinType',
#    'skinTone',
#    'eyeColor',
#    'age',
#    'beautyInsider',
#    'IncentivizedReview',
#    'StaffContext'],
#   'TagDimensionsOrder': ['Pro'],
#   'ClientResponses': [],
#   'TotalPositiveFeedbackCount': 185,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-09-02T02:05:04.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': ['yesvibr'],
#   'AuthorId': '2135374503',
#   'Helpfulness': 0.864486,
#   'SubmissionTime': '2015-05-26T21:29:04.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'One of the best',
#   'TotalFeedbackCount': 214,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {'Pro': {'Label': 'Pros',
#     'Values': ['buildable coverage', 'long wearing', 'oil-free'],
#     'Id': 'Pro'}},
#   'SecondaryRatings': {},
#   'Badges': {'yesvibr': {'ContentType': 'REVIEW',
#     'Id': 'yesvibr',
#     'BadgeType': 'Custom'}},
#   'SubmissionId': 'sfg08b27eylbhbn7vmr8jfvdi',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2015-05-26T21:30:06.000+00:00',
#   'Id': '46090620',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'morghymel',
#   'Rating': 5,
#   'ReviewText': "I have dry skin and this foundation gives me life! Doesn't settle in fine lines! I'm in love!",
#   'ContextDataValues': {'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 34,
#   'RatingRange': 5,
#   'CampaignId': None,
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['IncentivizedReview', 'StaffContext'],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 184,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-09-02T19:29:22.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': [],
#   'AuthorId': '5621824259',
#   'Helpfulness': 0.844037,
#   'SubmissionTime': '2016-06-09T15:48:27.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'YASSS',
#   'TotalFeedbackCount': 218,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {},
#   'SubmissionId': 'pxrogyaz8i4kl2pp1vtiw2r78',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2016-06-09T16:00:05.000+00:00',
#   'Id': '67804660',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'MeiYong',
#   'Rating': 5,
#   'ReviewText': "Let me start off by saying I have dark acne scars and oily skin, and that I don't think I can fully how thin and pigmented this foundation is, but I will try. I've had terrible dark spots from old acne since I was in my early-mid teens. And since then, I've been on the search for a full coverage foundation/cc cream   concealer that didn't make me look and feel like a walking cake. I've tried it all. To get a good amount of coverage, I've had to sacrifice a significant amount of time, foundation, and a natural look--- so my acne scars would disappear but the trade-off was that my face would be cakey and by the end of the day, thick and oily. I didn't really believe the hype when I heard about this foundation. But it does do what it claims to do. When I wore  this foundation out for the first time, I received so many compliments on how much better my skin looked and how much it's improved. My face was dewy, (seemingly) clear, and light--- as opposed to my usual oily then dry then back to oily, (kind of) clear, cakey skin. It's expensive for foundation, but it's worth it because you don't even need to put on so much. If I had to pick a downside to this foundation, it'd be that it enhances the fine lines underneath my eyes when I smile. That and also, I can't seem to find the perfect color yet. I currently wear 5.75, but I'm looking for something more yellow toned. Suggestions would be appreciated!",
#   'ContextDataValues': {'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 9,
#   'RatingRange': 5,
#   'CampaignId': None,
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['IncentivizedReview', 'StaffContext'],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 134,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-09-01T03:06:08.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': [],
#   'AuthorId': '7046955023',
#   'Helpfulness': 0.937063,
#   'SubmissionTime': '2016-12-11T02:07:01.000+00:00',
#   'AdditionalFields': {},
#   'Title': '"Your skin has gotten so much better!"',
#   'TotalFeedbackCount': 143,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {},
#   'SubmissionId': '27kk32oxn5ke5x4ry5aimm94h',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2016-12-11T02:15:03.000+00:00',
#   'Id': '78048855',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'TanyaMel',
#   'Rating': 4,
#   'ReviewText': "I've sampled almost every foundation Sephora carries on a mission to find something for my dry/combo, slightly red skin. This stuff is AMAZING. Medium coverage, blurs, satin finish and looks flawless. Only gripes: 1) Sephora didn't carry it, so finding a shade took a few online orders & 2) It DOES transfer if you touch your face- but you can use a more intense setting spray I guess. Even if you're oily, try a sample! A matte primer/setting powder in areas could be your fix. The price is intense, but I'd wanted to try it for months and it ended up being HG.\nFor reference: whole numbers = neutral, .25 = leans warm/yellow, and .75 = leans pink/cool.",
#   'ContextDataValues': {'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 7,
#   'RatingRange': 5,
#   'CampaignId': None,
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['IncentivizedReview', 'StaffContext'],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 117,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-08-31T05:48:46.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': [],
#   'AuthorId': '2824710167',
#   'Helpfulness': 0.943548,
#   'SubmissionTime': '2015-06-04T15:59:18.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'HOLY. GRAIL.',
#   'TotalFeedbackCount': 124,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {},
#   'SubmissionId': '630ie64g7ird58x9j5c8r49e5',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2015-06-04T16:00:06.000+00:00',
#   'Id': '46299315',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'chloe101',
#   'Rating': 5,
#   'ReviewText': 'If you are light/medium skin tone with yellow undertones (NC25-NC30) try shade 3.5!!! It took me a lot of trial and error to find the perfect shade. But 3.5 is perfect! I tried shades 5.75, 5, 4.5 and I was shocked when the very nice girl suggested 3.5. But it worked! I have dry skin in the winter and this does not accentuate it. I do use smashbox photo finish light primer over my heavy moisturizer. This gives me a natural look while covering my redness and blemishes. Lasts most of the day. I do powder once during the day usually. Highly recommend.',
#   'ContextDataValues': {},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 6,
#   'RatingRange': 5,
#   'CampaignId': None,
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': [],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 97,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-08-29T19:40:24.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': [],
#   'AuthorId': '1097610332',
#   'Helpfulness': 0.941748,
#   'SubmissionTime': '2015-02-12T16:26:56.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'great for dry skin',
#   'TotalFeedbackCount': 103,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {},
#   'SubmissionId': '9vhex3q6jx81e0hmi04c8xxnt',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2015-02-12T16:30:06.000+00:00',
#   'Id': '42641147',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'livforg',
#   'Rating': 5,
#   'ReviewText': 'I was a makeup artist for 10 years and have used just about every product out there trying to find the perfect balance of a natural looking coverage with a luminous finish, but not oily looking and the most important thing....not cause breakouts! I received a sample of this at my local Sephora store and fell in love with the finish, long wearability, and the slight glow, however the color she gave me was just a bit off. The first sample color was 5, but was too dark. Back at the store a different beauty advisor recommended the shade 3.5, which is absolutely perfect! I will never go back to powder again!',
#   'ContextDataValues': {'skinType': {'Value': 'combination',
#     'Id': 'skinType',
#     'ValueLabel': 'Combination',
#     'DimensionLabel': 'Skin Type'},
#    'beautyInsider': {'Value': 'yesvib',
#     'Id': 'beautyInsider',
#     'ValueLabel': "Yes - I'm a VIB ",
#     'DimensionLabel': 'Beauty Insider'},
#    'eyeColor': {'Value': 'hazel',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Hazel',
#     'DimensionLabel': 'Eye Color'},
#    'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'skinTone': {'Value': 'light',
#     'Id': 'skinTone',
#     'ValueLabel': 'Light',
#     'DimensionLabel': 'Skin Tone'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'},
#    'age': {'Value': '35to44',
#     'Id': 'age',
#     'ValueLabel': '35-44',
#     'DimensionLabel': 'Age'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 6,
#   'RatingRange': 5,
#   'CampaignId': 'BV_RATING_SUMMARY',
#   'UserLocation': 'San Diego, CA',
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['skinType',
#    'skinTone',
#    'eyeColor',
#    'age',
#    'beautyInsider',
#    'IncentivizedReview',
#    'StaffContext'],
#   'TagDimensionsOrder': ['Pro'],
#   'ClientResponses': [],
#   'TotalPositiveFeedbackCount': 86,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-08-24T04:06:31.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': ['yesvib'],
#   'AuthorId': '1284606990',
#   'Helpfulness': 0.934783,
#   'SubmissionTime': '2015-08-09T17:00:24.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'Amazing!',
#   'TotalFeedbackCount': 92,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {'Pro': {'Label': 'Pros',
#     'Values': ['long wearing',
#      'buildable coverage',
#      'feels incredible to the touch'],
#     'Id': 'Pro'}},
#   'SecondaryRatings': {},
#   'Badges': {'yesvib': {'ContentType': 'REVIEW',
#     'Id': 'yesvib',
#     'BadgeType': 'Custom'}},
#   'SubmissionId': '2aeeixsuylqigurnmi8kdmkmr',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2015-08-09T17:15:05.000+00:00',
#   'Id': '48250240',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'carla111',
#   'Rating': 5,
#   'ReviewText': 'I have used this foundation for years and loved it. But, I could only use it in the summer time because the shade I bought was a bit too....orange. I was so glad when Sephora started carrying it, because it meant that I could maybe finally find the correct shade. I called and was told by a rep what the numbers meant, and I read other online reviews that said what was cool or warm. However, I still ended up with the exact opposite of what I needed. After the second phone call to Sephora, they got me exactly what I needed. For reference, the whole numbers are a neutral color. The ones ending in .5 are golden. The.25 ones are pinkish. And, the .75 are "warm neutral golden." The is exactly what the second Sephora rep told me.\n\nFor reference, I am a perfect match to YSL Fusion Ink Foundation in the shade BR30 (cool almond). I love the Fusion Ink, but I needed something with a bit more coverage, staying power and without sunscreen for my upcoming wedding.\n\nI ended up getting the Luminous Silk in 5.25. (my old shade that was too orange was 5.5). The 5.25 is absolutely perfect.\n\nI wish they would publish what the numbers mean online in the description. It would have saved me numerous returns and hassle trying to find the right one.\n\nI have oily skin, and this stays on all day with only minor blotting. Feels light and doesn\'t look cakey.\n\nSometimes its hard for us pinky gals to find the right color because so many foundations lean towards the yellow side.',
#   'ContextDataValues': {'skinType': {'Value': 'oily',
#     'Id': 'skinType',
#     'ValueLabel': 'Oily',
#     'DimensionLabel': 'Skin Type'},
#    'beautyInsider': {'Value': 'yesvibr',
#     'Id': 'beautyInsider',
#     'ValueLabel': "Yes - I'm a VIB Rouge ",
#     'DimensionLabel': 'Beauty Insider'},
#    'eyeColor': {'Value': 'blue',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Blue',
#     'DimensionLabel': 'Eye Color'},
#    'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'skinTone': {'Value': 'light',
#     'Id': 'skinTone',
#     'ValueLabel': 'Light',
#     'DimensionLabel': 'Skin Tone'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'},
#    'age': {'Value': '35to44',
#     'Id': 'age',
#     'ValueLabel': '35-44',
#     'DimensionLabel': 'Age'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 6,
#   'RatingRange': 5,
#   'CampaignId': 'BV_RATING_SUMMARY',
#   'UserLocation': 'Omaha, NE',
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['skinType',
#    'skinTone',
#    'eyeColor',
#    'age',
#    'beautyInsider',
#    'IncentivizedReview',
#    'StaffContext'],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 86,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-09-03T12:37:27.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': ['yesvibr'],
#   'AuthorId': '750772015',
#   'Helpfulness': 0.934783,
#   'SubmissionTime': '2015-06-25T20:43:40.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'flawless coverage',
#   'TotalFeedbackCount': 92,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {'yesvibr': {'ContentType': 'REVIEW',
#     'Id': 'yesvibr',
#     'BadgeType': 'Custom'}},
#   'SubmissionId': 'loo1sv55veskvlm31mfer08jz',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2015-06-25T20:45:05.000+00:00',
#   'Id': '47240251',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'ToriNatelB',
#   'Rating': 5,
#   'ReviewText': "This is perfect for a more yellow-toned skin base. If you have oily skin, I would not recommend this foundation. If your only problem is your t-zone a great primer (like make-up forever's) would take care of that and a good translucent setting powder. It is light weight and sheer coverage which you can build up if you feel the need. When you wear this foundation you glow. It is also perfectly safe for sensitive skin, as mine is. It is however much, much to little product for so much money.",
#   'ContextDataValues': {'skinType': {'Value': 'combination',
#     'Id': 'skinType',
#     'ValueLabel': 'Combination',
#     'DimensionLabel': 'Skin Type'},
#    'beautyInsider': {'Value': 'yesvibr',
#     'Id': 'beautyInsider',
#     'ValueLabel': "Yes - I'm a VIB Rouge ",
#     'DimensionLabel': 'Beauty Insider'},
#    'eyeColor': {'Value': 'hazel',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Hazel',
#     'DimensionLabel': 'Eye Color'},
#    'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'skinTone': {'Value': 'fair',
#     'Id': 'skinTone',
#     'ValueLabel': 'Fair',
#     'DimensionLabel': 'Skin Tone'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'},
#    'age': {'Value': '18to24',
#     'Id': 'age',
#     'ValueLabel': '18-24',
#     'DimensionLabel': 'Age'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 6,
#   'RatingRange': 5,
#   'CampaignId': 'BV_RATING_SUMMARY',
#   'UserLocation': 'Columbus, Ohio',
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['skinType',
#    'skinTone',
#    'eyeColor',
#    'age',
#    'beautyInsider',
#    'IncentivizedReview',
#    'StaffContext'],
#   'TagDimensionsOrder': ['Pro'],
#   'ClientResponses': [],
#   'TotalPositiveFeedbackCount': 82,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-08-29T19:40:12.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': ['yesvibr'],
#   'AuthorId': '6295297429',
#   'Helpfulness': 0.931818,
#   'SubmissionTime': '2016-03-30T00:48:45.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'Wonderful!',
#   'TotalFeedbackCount': 88,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {'Pro': {'Label': 'Pros',
#     'Values': ['long wearing',
#      'buildable coverage',
#      'sheer-to-light',
#      'radiant',
#      'hydrating',
#      'natural',
#      'not enough product for high price'],
#     'Id': 'Pro'}},
#   'SecondaryRatings': {},
#   'Badges': {'yesvibr': {'ContentType': 'REVIEW',
#     'Id': 'yesvibr',
#     'BadgeType': 'Custom'}},
#   'SubmissionId': '2dt3trlpvrgf8d8rhn6m47788',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2016-03-30T01:00:09.000+00:00',
#   'Id': '63159107',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'beauty258',
#   'Rating': 5,
#   'ReviewText': "I am a makeup junkie, (as i am sure a lot of Sephora customers are), my most hoarded product is foundation. i am always looking for a long lasting, full coverage, natural finish foundation. I have searched and tried so many, both high end and drugstore. I have found some great products, but none compare to this foundation. I have acne-prone skin, with a lot of redness and scarring. This foundation looks AMAZING. It truly doesn't look or feel like you are wearing a ton of makeup. I worked out with it on to test the longevity and it looked just as good after as it did when i applied it. I don't know why it took me so long to try this foundation (maybe the price). I am so glad i got it.",
#   'ContextDataValues': {'skinType': {'Value': 'combination',
#     'Id': 'skinType',
#     'ValueLabel': 'Combination',
#     'DimensionLabel': 'Skin Type'},
#    'beautyInsider': {'Value': 'yes',
#     'Id': 'beautyInsider',
#     'ValueLabel': "Yes - I'm a Beauty Insider",
#     'DimensionLabel': 'Beauty Insider'},
#    'eyeColor': {'Value': 'brown',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Brown',
#     'DimensionLabel': 'Eye Color'},
#    'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'skinTone': {'Value': 'light',
#     'Id': 'skinTone',
#     'ValueLabel': 'Light',
#     'DimensionLabel': 'Skin Tone'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'},
#    'age': {'Value': '18to24',
#     'Id': 'age',
#     'ValueLabel': '18-24',
#     'DimensionLabel': 'Age'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 7,
#   'RatingRange': 5,
#   'CampaignId': 'BV_RATING_SUMMARY',
#   'UserLocation': 'san rafael, CA',
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['skinType',
#    'skinTone',
#    'eyeColor',
#    'age',
#    'beautyInsider',
#    'IncentivizedReview',
#    'StaffContext'],
#   'TagDimensionsOrder': ['Pro'],
#   'ClientResponses': [],
#   'TotalPositiveFeedbackCount': 74,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-07-19T14:56:07.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': ['beautyInsider'],
#   'AuthorId': '2664241742',
#   'Helpfulness': 0.91358,
#   'SubmissionTime': '2016-04-30T15:53:35.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'My new holy grail',
#   'TotalFeedbackCount': 81,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {'Pro': {'Label': 'Pros',
#     'Values': ['long wearing', 'buildable coverage', 'natural radiance'],
#     'Id': 'Pro'}},
#   'SecondaryRatings': {},
#   'Badges': {'beautyInsider': {'ContentType': 'REVIEW',
#     'Id': 'beautyInsider',
#     'BadgeType': 'Custom'}},
#   'SubmissionId': 'hhtlwmvm7zbyj0jeremz5tks8',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2016-04-30T16:00:04.000+00:00',
#   'Id': '64939239',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'kreyne',
#   'Rating': 5,
#   'ReviewText': 'I just finished a long search for my perfect foundations and this Luminous Silk Foundation is now a favorite. This is the foundation I wear that leaves people saying, "You\'re wearing makeup?!" \n\nThe coverage is light (build-able to medium) and can be applied with fingers, brush, or sponge. If you\'ve got pretty great skin but want to take it to a next-level silkiness and glow, then this is for you. My skin isn\'t like that, though! I have a lot of pigmentation (post-inflammation, sun damage, plus melasma), but I still like it because it gives me something between au naturel and full-on, I\'m-definitely-wearing-foundation makeup (for that I rely on Makeup Forever\'s HD Invisible Cover foundation). You can still see my spots underneath, but they\'re lighter and I love the finish of this foundation: lightweight, luminous, and natural. And for my dry skin, this formula is nice---it stays, but it doesn\'t turn cakey or settle in weirdly.',
#   'ContextDataValues': {'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 6,
#   'RatingRange': 5,
#   'CampaignId': None,
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['IncentivizedReview', 'StaffContext'],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 62,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-07-30T20:41:36.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': [],
#   'AuthorId': '1219710631',
#   'Helpfulness': 0.911765,
#   'SubmissionTime': '2016-08-23T01:08:14.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'Lightweight, luminous, and natural',
#   'TotalFeedbackCount': 68,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {},
#   'SubmissionId': 'hyq4gt5ko0ahssjideieqc3sx',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2016-08-23T17:15:04.000+00:00',
#   'Id': '72212543',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'chrissykidd',
#   'Rating': 5,
#   'ReviewText': "I'm oily and I have somehow managed to make this foundation work for my skin. I put on the MUFE Step 1 mattifying primer in my t-zone along with the Too Faced HangoverRx primer for the rest of my face. Okay, so recently I flew to the UK and I put on my make up before my flight. I also bathed my face in the UD setting spray afterwards. When I landed this foundation did not move whatsoever. It did not make me a greaseball, I just looked dewy. Even when I kept the make up on for about 5 more hours I had no problems. It did not break me out. After that experience this foundation has been my holy grail. In total I wore this foundation for 25 hours. I could not believe this was possible. I believe this foundation can be worn for all skin types, I would suggest to have a very good primer that suits your skin type.",
#   'ContextDataValues': {'skinType': {'Value': 'oily',
#     'Id': 'skinType',
#     'ValueLabel': 'Oily',
#     'DimensionLabel': 'Skin Type'},
#    'beautyInsider': {'Value': 'yesvibr',
#     'Id': 'beautyInsider',
#     'ValueLabel': "Yes - I'm a VIB Rouge ",
#     'DimensionLabel': 'Beauty Insider'},
#    'eyeColor': {'Value': 'brown',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Brown',
#     'DimensionLabel': 'Eye Color'},
#    'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'skinTone': {'Value': 'medium',
#     'Id': 'skinTone',
#     'ValueLabel': 'Medium',
#     'DimensionLabel': 'Skin Tone'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'},
#    'age': {'Value': '18to24',
#     'Id': 'age',
#     'ValueLabel': '18-24',
#     'DimensionLabel': 'Age'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 2,
#   'RatingRange': 5,
#   'CampaignId': 'BV_RATING_SUMMARY',
#   'UserLocation': 'Winston Salem, NC',
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['skinType',
#    'skinTone',
#    'eyeColor',
#    'age',
#    'beautyInsider',
#    'IncentivizedReview',
#    'StaffContext'],
#   'TagDimensionsOrder': ['Pro'],
#   'ClientResponses': [],
#   'TotalPositiveFeedbackCount': 61,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-08-28T12:46:04.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': ['yesvibr'],
#   'AuthorId': '5140351397',
#   'Helpfulness': 0.968254,
#   'SubmissionTime': '2015-07-02T03:20:54.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'Could not be more in love.',
#   'TotalFeedbackCount': 63,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {'Pro': {'Label': 'Pros',
#     'Values': ['buildable coverage', 'long wearing'],
#     'Id': 'Pro'}},
#   'SecondaryRatings': {},
#   'Badges': {'yesvibr': {'ContentType': 'REVIEW',
#     'Id': 'yesvibr',
#     'BadgeType': 'Custom'}},
#   'SubmissionId': 'oz25tkn4amnqg01dgvsjd6cdv',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2015-07-02T03:30:02.000+00:00',
#   'Id': '47357250',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'chocoqueen',
#   'Rating': 4,
#   'ReviewText': "It is a truly silky smooth texture that doesn't feel heavy or overdone.  The only reason why I gave it 4 stars is because of misleading color patches/description.  I chose light with golden overtones for my white but easily tanning skin.  It was WaY too light!   I looked like a ghost.  So unless you are extremely pale, go a shade darker in the same tone or maybe even 2 shades.  I am keeping mine for those dark circles under eyes but I am planning to get the right shade next time.   Awesome product!",
#   'ContextDataValues': {'skinType': {'Value': 'normal',
#     'Id': 'skinType',
#     'ValueLabel': 'Normal',
#     'DimensionLabel': 'Skin Type'},
#    'beautyInsider': {'Value': 'yesvib',
#     'Id': 'beautyInsider',
#     'ValueLabel': "Yes - I'm a VIB ",
#     'DimensionLabel': 'Beauty Insider'},
#    'eyeColor': {'Value': 'blue',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Blue',
#     'DimensionLabel': 'Eye Color'},
#    'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'skinTone': {'Value': 'light',
#     'Id': 'skinTone',
#     'ValueLabel': 'Light',
#     'DimensionLabel': 'Skin Tone'},
#    'IncentivizedReview': {'Value': 'true',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'True',
#     'DimensionLabel': 'I received this product as a free sample'},
#    'age': {'Value': '45to54',
#     'Id': 'age',
#     'ValueLabel': '45-54',
#     'DimensionLabel': 'Age'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 2,
#   'RatingRange': 5,
#   'CampaignId': 'BV_RATING_SUMMARY',
#   'UserLocation': 'Illinois',
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['skinType',
#    'skinTone',
#    'eyeColor',
#    'age',
#    'beautyInsider',
#    'IncentivizedReview',
#    'StaffContext'],
#   'TagDimensionsOrder': ['Pro'],
#   'ClientResponses': [],
#   'TotalPositiveFeedbackCount': 59,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-09-03T02:06:43.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': ['yesvib', 'IncentivizedReviewBadge'],
#   'AuthorId': '1237919606',
#   'Helpfulness': 0.967213,
#   'SubmissionTime': '2016-12-14T02:13:45.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'Wonderful texture',
#   'TotalFeedbackCount': 61,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {'Pro': {'Label': 'Pros',
#     'Values': ['buildable coverage'],
#     'Id': 'Pro'}},
#   'SecondaryRatings': {},
#   'Badges': {'IncentivizedReviewBadge': {'ContentType': 'REVIEW',
#     'Id': 'IncentivizedReviewBadge',
#     'BadgeType': 'Custom'},
#    'yesvib': {'ContentType': 'REVIEW', 'Id': 'yesvib', 'BadgeType': 'Custom'}},
#   'SubmissionId': 'eeyk9uwuhznjgvcv0fbvif898',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2016-12-14T02:15:04.000+00:00',
#   'Id': '78191744',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'maggie4kids',
#   'Rating': 5,
#   'ReviewText': "Shade 4.75 [Medium NC30]. Lasts 6-8hrs. with primer. Great in photo's with no flashback and makes the skin look gorgeous. I use the Armani foundation brush and use 1 pump. I do not use this daily but for photo's or special occasions.",
#   'ContextDataValues': {'skinType': {'Value': 'combination',
#     'Id': 'skinType',
#     'ValueLabel': 'Combination',
#     'DimensionLabel': 'Skin Type'},
#    'beautyInsider': {'Value': 'yesvibr',
#     'Id': 'beautyInsider',
#     'ValueLabel': "Yes - I'm a VIB Rouge ",
#     'DimensionLabel': 'Beauty Insider'},
#    'eyeColor': {'Value': 'brown',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Brown',
#     'DimensionLabel': 'Eye Color'},
#    'skinTone': {'Value': 'medium',
#     'Id': 'skinTone',
#     'ValueLabel': 'Medium',
#     'DimensionLabel': 'Skin Tone'},
#    'age': {'Value': 'over54',
#     'Id': 'age',
#     'ValueLabel': 'over 54',
#     'DimensionLabel': 'Age'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 2,
#   'RatingRange': 5,
#   'CampaignId': 'BV_RATING_SUMMARY',
#   'UserLocation': 'Kaneohe, HI',
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['skinType',
#    'skinTone',
#    'eyeColor',
#    'age',
#    'beautyInsider'],
#   'TagDimensionsOrder': ['Pro'],
#   'ClientResponses': [],
#   'TotalPositiveFeedbackCount': 59,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-09-03T13:04:38.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': ['yesvibr'],
#   'AuthorId': '962115242',
#   'Helpfulness': 0.967213,
#   'SubmissionTime': '2015-03-26T08:20:43.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'Satiny silk finish',
#   'TotalFeedbackCount': 61,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {'Pro': {'Label': 'Pros',
#     'Values': ['buildable coverage'],
#     'Id': 'Pro'}},
#   'SecondaryRatings': {},
#   'Badges': {'yesvibr': {'ContentType': 'REVIEW',
#     'Id': 'yesvibr',
#     'BadgeType': 'Custom'}},
#   'SubmissionId': '2o19ymmviczisrr7ccaxsatwl',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2015-03-26T09:15:05.000+00:00',
#   'Id': '44446004',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'EBecks',
#   'Rating': 5,
#   'ReviewText': 'This foundation is my Holy Grail foundation. Its natural looking and holds up on the skin well. It also photographs beautifully. Its worth the price, and the only foundation that I continue to repurchase again and again. Stunning',
#   'ContextDataValues': {'skinType': {'Value': 'dry',
#     'Id': 'skinType',
#     'ValueLabel': 'Dry',
#     'DimensionLabel': 'Skin Type'},
#    'beautyInsider': {'Value': 'yesvibr',
#     'Id': 'beautyInsider',
#     'ValueLabel': "Yes - I'm a VIB Rouge ",
#     'DimensionLabel': 'Beauty Insider'},
#    'eyeColor': {'Value': 'blue',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Blue',
#     'DimensionLabel': 'Eye Color'},
#    'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'skinTone': {'Value': 'light',
#     'Id': 'skinTone',
#     'ValueLabel': 'Light',
#     'DimensionLabel': 'Skin Tone'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'},
#    'age': {'Value': '25to34',
#     'Id': 'age',
#     'ValueLabel': '25-34',
#     'DimensionLabel': 'Age'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 4,
#   'RatingRange': 5,
#   'CampaignId': 'BV_RATING_SUMMARY',
#   'UserLocation': 'Madison , WI',
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['skinType',
#    'skinTone',
#    'eyeColor',
#    'age',
#    'beautyInsider',
#    'IncentivizedReview',
#    'StaffContext'],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 58,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-08-19T11:13:55.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': ['yesvibr'],
#   'AuthorId': '1355228953',
#   'Helpfulness': 0.935484,
#   'SubmissionTime': '2015-12-06T18:10:53.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'Holy Grail',
#   'TotalFeedbackCount': 62,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {'yesvibr': {'ContentType': 'REVIEW',
#     'Id': 'yesvibr',
#     'BadgeType': 'Custom'}},
#   'SubmissionId': '3k1fgz8k6gaeigpqc5bbpo4nu',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2015-12-06T18:15:06.000+00:00',
#   'Id': '56355820',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'Nicestgirlever',
#   'Rating': 5,
# ...
#  {'UserNickname': 'elegantella',
#   'Rating': 3,
#   'ReviewText': "A good foundation? Yes. A transformative difference? No. \n\nFor the price and rave reviews, I was expecting a lot more than this. Don't get me wrong, it's a good foundation.... but does it make my face look like luminous silk? No way. I was applying with a sponge and actually bought a brush specifically for this because reviews kept saying a brush was better. It made no difference whatsoever, so there's more money I'll never see again!\n\nI will say that when I put my ambient hourglass lighting powder on top, the effect is wonderful. But the lighting powder looks almost as good on my bare skin as on this makeup, so for a regular work day I have quit applying foundation altogether.  I now have a ton of this left and only use it for a special night out.\n\nFor over-the-top prices I expect over-the-top results, and this just doesn't deliver.",
#   'ContextDataValues': {'skinType': {'Value': 'normal',
#     'Id': 'skinType',
#     'ValueLabel': 'Normal',
#     'DimensionLabel': 'Skin Type'},
#    'eyeColor': {'Value': 'hazel',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Hazel',
#     'DimensionLabel': 'Eye Color'},
#    'skinConcerns': {'Value': 'dullness',
#     'Id': 'skinConcerns',
#     'ValueLabel': 'Dullness',
#     'DimensionLabel': 'Skin concerns'},
#    'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'hairColor': {'Value': 'brunette',
#     'Id': 'hairColor',
#     'ValueLabel': 'Brunette',
#     'DimensionLabel': 'Hair color'},
#    'skinTone': {'Value': 'fair',
#     'Id': 'skinTone',
#     'ValueLabel': 'Fair',
#     'DimensionLabel': 'Skin Tone'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'}},
#   'ProductId': '1359603',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 0,
#   'RatingRange': 5,
#   'CampaignId': None,
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['eyeColor',
#    'hairColor',
#    'skinTone',
#    'skinType',
#    'skinConcerns',
#    'IncentivizedReview',
#    'StaffContext'],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 1,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-07-09T02:09:08.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': [],
#   'AuthorId': '21807889100',
#   'Helpfulness': 1.0,
#   'SubmissionTime': '2019-07-03T14:09:32.000+00:00',
#   'AdditionalFields': {'sociallockup': {'Label': 'sociallockup',
#     'Value': 'avatar=https://sephora.i.lithium.com/t5/image/serverpage/avatar-name/default-avatar/avatar-theme/sephora/avatar-collection/sephora/avatar-display-size/profile/version/2?xdesc=1.0|biBadgeUrl=/html/rank_icons/birole_insider.svg|engagementBadgeUrl=/html/rank_icons/rank_rookie-01.svg|biTier=BI',
#     'Id': 'sociallockup'}},
#   'Title': 'Not that impressive!!!!',
#   'AdditionalFieldsOrder': ['sociallockup'],
#   'TotalFeedbackCount': 1,
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {},
#   'SubmissionId': 'p2e5vd54xdvtsolc1sgcgdq5m',
#   'IsSyndicated': False,
#   'IsRecommended': False,
#   'LastModeratedTime': '2019-07-05T14:15:08.000+00:00',
#   'Id': '130182570',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'ashes1989',
#   'Rating': 5,
#   'ReviewText': "Well, after nearly 30 years I finally found my holy grail foundation. After watching Jeffree Star rave about it in his videos I decided to try it today. My wallet is going to hate me forever. Dewy without feeling the slightest bit oily, good coverage and leaves the skin looking absolutely flawless it's almost plastic.",
#   'ContextDataValues': {'skinType': {'Value': 'combination',
#     'Id': 'skinType',
#     'ValueLabel': 'Combination',
#     'DimensionLabel': 'Skin Type'},
#    'eyeColor': {'Value': 'blue',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Blue',
#     'DimensionLabel': 'Eye Color'},
#    'skinConcerns': {'Value': 'acne',
#     'Id': 'skinConcerns',
#     'ValueLabel': 'Acne',
#     'DimensionLabel': 'Skin concerns'},
#    'hairColor': {'Value': 'brunette',
#     'Id': 'hairColor',
#     'ValueLabel': 'Brunette',
#     'DimensionLabel': 'Hair color'},
#    'skinTone': {'Value': 'fair',
#     'Id': 'skinTone',
#     'ValueLabel': 'Fair',
#     'DimensionLabel': 'Skin Tone'},
#    'age': {'Value': 'over54',
#     'Id': 'age',
#     'ValueLabel': 'over 54',
#     'DimensionLabel': 'Age'}},
#   'ProductId': '1359538',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 0,
#   'RatingRange': 5,
#   'CampaignId': None,
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['eyeColor',
#    'hairColor',
#    'skinTone',
#    'skinType',
#    'skinConcerns',
#    'age'],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 1,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-05-04T17:35:22.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': [],
#   'AuthorId': '8938611669',
#   'Helpfulness': 1.0,
#   'SubmissionTime': '2019-02-10T00:34:26.000+00:00',
#   'AdditionalFields': {'sociallockup': {'Label': 'sociallockup',
#     'Value': 'avatar=https://sephora.i.lithium.com/t5/image/serverpage/avatar-name/default-avatar/avatar-theme/sephora/avatar-collection/sephora/avatar-display-size/profile/version/2?xdesc=1.0|biBadgeUrl=/html/rank_icons/birole_rouge.png|engagementBadgeUrl=/html/rank_icons/rank_rookie-01.png|biTier=rouge',
#     'Id': 'sociallockup'}},
#   'Title': 'Holy Grail',
#   'AdditionalFieldsOrder': ['sociallockup'],
#   'TotalFeedbackCount': 1,
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {},
#   'SubmissionId': '1yfkyqq2b3mi8snf0f28y5r59',
#   'IsSyndicated': False,
#   'IsRecommended': True,
#   'LastModeratedTime': '2019-02-10T00:45:04.000+00:00',
#   'Id': '124335135',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'AllieMarie73',
#   'Rating': 5,
#   'ReviewText': "This is the BEST foundation out there! If you don't think so I dare you to find something better!",
#   'ContextDataValues': {'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 1,
#   'RatingRange': 5,
#   'CampaignId': None,
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['IncentivizedReview', 'StaffContext'],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 1,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2016-07-17T23:30:04.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': [],
#   'AuthorId': '5803795148',
#   'Helpfulness': 0.5,
#   'SubmissionTime': '2016-07-17T23:28:31.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'worth every penny',
#   'TotalFeedbackCount': 2,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {},
#   'SubmissionId': 'pi9wqc5lgteqbie3c0uiye38n',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2016-07-17T23:30:04.000+00:00',
#   'Id': '69841742',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'Erihart',
#   'Rating': 5,
#   'ReviewText': "This is one of the few foundations that works well with my combo skin and doesn't come off of my nose in an hour!",
#   'ContextDataValues': {},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 1,
#   'RatingRange': 5,
#   'CampaignId': None,
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': [],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 1,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2017-08-17T05:00:03.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': [],
#   'AuthorId': '7554717370',
#   'Helpfulness': 0.5,
#   'SubmissionTime': '2017-08-17T04:55:21.000+00:00',
#   'AdditionalFields': {},
#   'Title': 'I love this foundation',
#   'TotalFeedbackCount': 2,
#   'AdditionalFieldsOrder': [],
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {},
#   'SubmissionId': '2i9txroc382lpnvlwfjvlh1uc',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2017-08-17T05:00:03.000+00:00',
#   'Id': '102666621',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'cmw28',
#   'Rating': 5,
#   'ReviewText': "I've died and gone to foundation heaven. This stuff is amazing! Works best with a primer! I thought it was a bit pricey at first too but so worth it!",
#   'ContextDataValues': {'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'}},
#   'ProductId': 'P393401',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 0,
#   'RatingRange': 5,
#   'CampaignId': None,
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['IncentivizedReview', 'StaffContext'],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 1,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2015-05-14T22:15:05.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': [],
#   'AuthorId': '1670428363',
#   'Helpfulness': 1.0,
#   'SubmissionTime': '2015-05-14T22:00:12.000+00:00',
#   'AdditionalFields': {},
#   'TotalFeedbackCount': 1,
#   'AdditionalFieldsOrder': [],
#   'Title': None,
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {},
#   'SubmissionId': 'a00nl5wy447fbm8l4uy58fxt7',
#   'IsSyndicated': False,
#   'IsRecommended': None,
#   'LastModeratedTime': '2015-05-14T22:15:05.000+00:00',
#   'Id': '45803415',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'Oggiedog',
#   'Rating': 5,
#   'ReviewText': "I've tried many brands and at first couldn't tell much difference just looking in the mirror, but when I saw my skin in a photo, well wow! my skin looked great. I love the finish. It's a bit thicker in texture compared to some other light coverage foundations, so it takes a bit more blending, but it's worth it. I highly recommend this.",
#   'ContextDataValues': {'skinType': {'Value': 'combination',
#     'Id': 'skinType',
#     'ValueLabel': 'Combination',
#     'DimensionLabel': 'Skin Type'},
#    'eyeColor': {'Value': 'blue',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Blue',
#     'DimensionLabel': 'Eye Color'},
#    'skinConcerns': {'Value': 'sunDamage',
#     'Id': 'skinConcerns',
#     'ValueLabel': 'Sun damage',
#     'DimensionLabel': 'Skin concerns'},
#    'StaffContext': {'Value': 'false',
#     'Id': 'StaffContext',
#     'ValueLabel': 'No',
#     'DimensionLabel': 'I am a Sephora employee'},
#    'hairColor': {'Value': 'auburn',
#     'Id': 'hairColor',
#     'ValueLabel': 'Auburn',
#     'DimensionLabel': 'Hair color'},
#    'skinTone': {'Value': 'fair',
#     'Id': 'skinTone',
#     'ValueLabel': 'Fair',
#     'DimensionLabel': 'Skin Tone'},
#    'IncentivizedReview': {'Value': 'false',
#     'Id': 'IncentivizedReview',
#     'ValueLabel': 'False',
#     'DimensionLabel': 'I received this product as a free sample'},
#    'age': {'Value': 'over54',
#     'Id': 'age',
#     'ValueLabel': 'over 54',
#     'DimensionLabel': 'Age'}},
#   'ProductId': '1359611',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 0,
#   'RatingRange': 5,
#   'CampaignId': None,
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['eyeColor',
#    'hairColor',
#    'skinTone',
#    'skinType',
#    'skinConcerns',
#    'age',
#    'IncentivizedReview',
#    'StaffContext'],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 1,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-05-15T21:52:35.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': [],
#   'AuthorId': '5459240526',
#   'Helpfulness': 1.0,
#   'SubmissionTime': '2019-03-29T18:03:21.000+00:00',
#   'AdditionalFields': {'sociallockup': {'Label': 'sociallockup',
#     'Value': 'avatar=https://sephora.i.lithium.com/t5/image/serverpage/avatar-name/default-avatar/avatar-theme/sephora/avatar-collection/sephora/avatar-display-size/profile/version/2?xdesc=1.0|biBadgeUrl=/html/rank_icons/birole_vib.png|engagementBadgeUrl=/html/rank_icons/rank_rookie-01.png|biTier=vib',
#     'Id': 'sociallockup'}},
#   'Title': 'Excellent',
#   'AdditionalFieldsOrder': ['sociallockup'],
#   'TotalFeedbackCount': 1,
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {},
#   'SubmissionId': 'i472fjvpwn5tya5lkbhnbdhe1',
#   'IsSyndicated': False,
#   'IsRecommended': True,
#   'LastModeratedTime': '2019-03-29T18:15:07.000+00:00',
#   'Id': '125957122',
#   'ContentLocale': 'en_US'},
#  {'UserNickname': 'reina4',
#   'Rating': 5,
#   'ReviewText': 'Hjdjdjdjxjdjdjdjdjdjdjdjdjdjdjdkdjdjdjddjdjjddjdjsjsbshsnsnsns',
#   'ContextDataValues': {'skinType': {'Value': 'combination',
#     'Id': 'skinType',
#     'ValueLabel': 'Combination',
#     'DimensionLabel': 'Skin Type'},
#    'eyeColor': {'Value': 'brown',
#     'Id': 'eyeColor',
#     'ValueLabel': 'Brown',
#     'DimensionLabel': 'Eye Color'},
#    'skinConcerns': {'Value': 'acne',
#     'Id': 'skinConcerns',
#     'ValueLabel': 'Acne',
#     'DimensionLabel': 'Skin concerns'},
#    'hairColor': {'Value': 'black',
#     'Id': 'hairColor',
#     'ValueLabel': 'Black',
#     'DimensionLabel': 'Hair color'},
#    'skinTone': {'Value': 'olive',
#     'Id': 'skinTone',
#     'ValueLabel': 'Olive',
#     'DimensionLabel': 'Skin Tone'}},
#   'ProductId': '1359553',
#   'Videos': [],
#   'CommentIds': [],
#   'Photos': [],
#   'TotalNegativeFeedbackCount': 3,
#   'RatingRange': 5,
#   'CampaignId': None,
#   'UserLocation': None,
#   'SecondaryRatingsOrder': [],
#   'TotalCommentCount': 0,
#   'ContextDataValuesOrder': ['eyeColor',
#    'hairColor',
#    'skinTone',
#    'skinType',
#    'skinConcerns'],
#   'ClientResponses': [],
#   'TagDimensionsOrder': [],
#   'TotalPositiveFeedbackCount': 1,
#   'IsRatingsOnly': False,
#   'LastModificationTime': '2019-04-27T22:51:21.000+00:00',
#   'Pros': None,
#   'ProductRecommendationIds': [],
#   'BadgesOrder': [],
#   'AuthorId': '10005773298',
#   'Helpfulness': 0.25,
#   'SubmissionTime': '2018-02-26T17:37:11.000+00:00',
#   'AdditionalFields': {'sociallockup': {'Label': 'sociallockup',
#     'Value': 'avatar=https://sephora.i.lithium.com/t5/image/serverpage/avatar-name/default-avatar/avatar-theme/sephora/avatar-collection/sephora/avatar-display-size/profile/version/2?xdesc=1.0|biBadgeUrl=/html/rank_icons/birole_insider.png|engagementBadgeUrl=/html/rank_icons/rank_rookie-01.png|biTier=bi',
#     'Id': 'sociallockup'}},
#   'AdditionalFieldsOrder': ['sociallockup'],
#   'TotalFeedbackCount': 4,
#   'Title': None,
#   'ModerationStatus': 'APPROVED',
#   'IsFeatured': False,
#   'Cons': None,
#   'TagDimensions': {},
#   'SecondaryRatings': {},
#   'Badges': {},
#   'SubmissionId': 'tnbwuyca4f6lzqu4bwgld2d41',
#   'IsSyndicated': False,
#   'IsRecommended': True,
#   'LastModeratedTime': '2018-02-26T17:45:05.000+00:00',
#   'Id': '110973658',
#   'ContentLocale': 'en_US'},
#  ...]

# %%
for i in range(len(reviews[0:10])):
    for j in reviews[i]:
        if j == 'UserNickname':
            print(reviews[i][j])
#     print(reviews[i])
# Out:
# marysells
# kinakelly
# chards
# stephsimas95
# Angiiie
# morghymel
# MeiYong
# TanyaMel
# chloe101
# livforg

# %%
reviews[1]['ContextDataValuesOrder']
# Out:
# ['skinTone', 'eyeColor', 'age', 'beautyInsider']

# %%
pprint(reviews[0])
# Out:
# {'AdditionalFields': {},
#  'AdditionalFieldsOrder': [],
#  'AuthorId': '1331777113',
#  'Badges': {'beautyInsider': {'BadgeType': 'Custom',
#                               'ContentType': 'REVIEW',
#                               'Id': 'beautyInsider'}},
#  'BadgesOrder': ['beautyInsider'],
#  'CampaignId': 'BV_RATING_SUMMARY',
#  'ClientResponses': [],
#  'CommentIds': [],
#  'Cons': None,
#  'ContentLocale': 'en_US',
#  'ContextDataValues': {'IncentivizedReview': {'DimensionLabel': 'I received '
#                                                                 'this product '
#                                                                 'as a free '
#                                                                 'sample',
#                                               'Id': 'IncentivizedReview',
#                                               'Value': 'false',
#                                               'ValueLabel': 'False'},
#                        'StaffContext': {'DimensionLabel': 'I am a Sephora '
#                                                           'employee',
#                                         'Id': 'StaffContext',
#                                         'Value': 'false',
#                                         'ValueLabel': 'No'},
#                        'age': {'DimensionLabel': 'Age',
#                                'Id': 'age',
#                                'Value': '45to54',
#                                'ValueLabel': '45-54'},
#                        'beautyInsider': {'DimensionLabel': 'Beauty Insider',
#                                          'Id': 'beautyInsider',
#                                          'Value': 'yes',
#                                          'ValueLabel': "Yes - I'm a Beauty "
#                                                        'Insider'},
#                        'eyeColor': {'DimensionLabel': 'Eye Color',
#                                     'Id': 'eyeColor',
#                                     'Value': 'hazel',
#                                     'ValueLabel': 'Hazel'},
#                        'skinTone': {'DimensionLabel': 'Skin Tone',
#                                     'Id': 'skinTone',
#                                     'Value': 'fair',
#                                     'ValueLabel': 'Fair'},
#                        'skinType': {'DimensionLabel': 'Skin Type',
#                                     'Id': 'skinType',
#                                     'Value': 'normal',
#                                     'ValueLabel': 'Normal'}},
#  'ContextDataValuesOrder': ['skinType',
#                             'skinTone',
#                             'eyeColor',
#                             'age',
#                             'beautyInsider',
#                             'IncentivizedReview',
#                             'StaffContext'],
#  'Helpfulness': 0.889286,
#  'Id': '63994076',
#  'IsFeatured': False,
#  'IsRatingsOnly': False,
#  'IsRecommended': None,
#  'IsSyndicated': False,
#  'LastModeratedTime': '2016-04-18T19:15:06.000+00:00',
#  'LastModificationTime': '2019-09-04T13:27:18.000+00:00',
#  'ModerationStatus': 'APPROVED',
#  'Photos': [],
#  'ProductId': 'P393401',
#  'ProductRecommendationIds': [],
#  'Pros': None,
#  'Rating': 5,
#  'RatingRange': 5,
#  'ReviewText': "I'd been on the fence about purchasing this for a long "
#                'time...I am a self-confessed product junkie and I have plenty '
#                'of foundations I should be using up before buying more. I '
#                'received a sample of this in 5.5, which is darker than I would '
#                "ever go. But I still tried it out of curiosity...it wasn't "
#                'really off the charts too dark and I loved the way it made my '
#                'skin look. Sooooo...during the 15% off VIB sale I bought this '
#                "in 4.5. The very first day I tried it, I still wasn't 100% "
#                'sold. But then I went to the DMV and after looking at my '
#                'license (and I assume my birthdate)  the clerk asked me what I '
#                "use on my skin.  No kidding!!! Ok, I'm sold. Hahaha! Buy it, "
#                'trust me.',
#  'SecondaryRatings': {},
#  'SecondaryRatingsOrder': [],
#  'SubmissionId': '2fkq9qns6ot235xrvactg59sc',
#  'SubmissionTime': '2016-04-18T19:00:26.000+00:00',
#  'TagDimensions': {'Pro': {'Id': 'Pro',
#                            'Label': 'Pros',
#                            'Values': ['buildable coverage']}},
#  'TagDimensionsOrder': ['Pro'],
#  'Title': 'It really is all that!!!',
#  'TotalCommentCount': 0,
#  'TotalFeedbackCount': 280,
#  'TotalNegativeFeedbackCount': 31,
#  'TotalPositiveFeedbackCount': 249,
#  'UserLocation': 'Tucson, AZ',
#  'UserNickname': 'marysells',
#  'Videos': []}

# %%
for i in reviews[0]:
    print(reviews[0])
# Out:
# marysells
# 5
# I'd been on the fence about purchasing this for a long time...I am a self-confessed product junkie and I have plenty of foundations I should be using up before buying more. I received a sample of this in 5.5, which is darker than I would ever go. But I still tried it out of curiosity...it wasn't really off the charts too dark and I loved the way it made my skin look. Sooooo...during the 15% off VIB sale I bought this in 4.5. The very first day I tried it, I still wasn't 100% sold. But then I went to the DMV and after looking at my license (and I assume my birthdate)  the clerk asked me what I use on my skin.  No kidding!!! Ok, I'm sold. Hahaha! Buy it, trust me.
# {'skinType': {'Value': 'normal', 'Id': 'skinType', 'ValueLabel': 'Normal', 'DimensionLabel': 'Skin Type'}, 'beautyInsider': {'Value': 'yes', 'Id': 'beautyInsider', 'ValueLabel': "Yes - I'm a Beauty Insider", 'DimensionLabel': 'Beauty Insider'}, 'eyeColor': {'Value': 'hazel', 'Id': 'eyeColor', 'ValueLabel': 'Hazel', 'DimensionLabel': 'Eye Color'}, 'StaffContext': {'Value': 'false', 'Id': 'StaffContext', 'ValueLabel': 'No', 'DimensionLabel': 'I am a Sephora employee'}, 'skinTone': {'Value': 'fair', 'Id': 'skinTone', 'ValueLabel': 'Fair', 'DimensionLabel': 'Skin Tone'}, 'IncentivizedReview': {'Value': 'false', 'Id': 'IncentivizedReview', 'ValueLabel': 'False', 'DimensionLabel': 'I received this product as a free sample'}, 'age': {'Value': '45to54', 'Id': 'age', 'ValueLabel': '45-54', 'DimensionLabel': 'Age'}}
# P393401
# []
# []
# []
# 31
# 5
# BV_RATING_SUMMARY
# Tucson, AZ
# []
# 0
# ['skinType', 'skinTone', 'eyeColor', 'age', 'beautyInsider', 'IncentivizedReview', 'StaffContext']
# ['Pro']
# []
# 249
# False
# 2019-09-04T13:27:18.000+00:00
# None
# []
# ['beautyInsider']
# 1331777113
# 0.889286
# 2016-04-18T19:00:26.000+00:00
# {}
# It really is all that!!!
# 280
# []
# APPROVED
# False
# None
# {'Pro': {'Label': 'Pros', 'Values': ['buildable coverage'], 'Id': 'Pro'}}
# {}
# {'beautyInsider': {'ContentType': 'REVIEW', 'Id': 'beautyInsider', 'BadgeType': 'Custom'}}
# 2fkq9qns6ot235xrvactg59sc
# False
# None
# 2016-04-18T19:15:06.000+00:00
# 63994076
# en_US

# %%
table
# Out:
# {'user_name': 'katieer',
#  'rating': 1,
#  'review_text': 'Not for oily skin. I was an oil slick in two hours. Otherwise I like the feel when first applied, but “natural finish” just isn’t for my skin type.'}

# %%
review_df = pd.DataFrame(columns = [
                                    'UserNickname,
                                    'Rating', 
                                    'IncentivizedReview',
                                    'SkinTone', 
                                    'SkinType',
                                    'ProductId', 
                                    'ReviewText',
                                    'Title',
                                    'UserLocation',
                                    'StaffContext'])

# %%
for i in range(len(reviews)):
    
    for j in reviews[i]:
        review_df['Username'] = reviews[0]['UserNickname']:
            
#     print(reviews[i])

# %%
review_df.head()

# %%
for review in reviews:
    for i in range(len(reviews)):
        table = {'Rating': reviews[i]['Rating']}

# %%
table
# Out:
# {'Rating': 3}

# %%
  'ReviewText': reviews[i]['Rating']
                'IncentivizedReview': 
                'SkinTone' 
                'SkinType'
                'ProductId'
                'Title',
                'UserLocation',
                'StaffContext''}
